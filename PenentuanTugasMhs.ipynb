# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardendyvatrizah-tech/MK-Kecerdasan-Buatan/blob/main/PenentuanTugasMhs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Penentuan Tugas Mahasiswa

# %% [markdown]
# Tulis NAMA dan NRP saudara (dengan mengganti Nama_Mahasiswa dan NRP_Mahasiswa pada cell di bawah ini)

# %%
student_name = 'Edwar Dendy Vatrizah'
student_id = '6022251057'

# %% [markdown]
# Selanjutnya, jalankan cell di bawah ini untuk menentukan tugas masing-masing mahasiswa

# %%
student_name = 'Edwar Dendy Vatrizah'
student_id = '6022251057'
import numpy as np

electronic_nose_type = ['Prediksi Populasi Mikroba','Klasifikasi Kualitas']
beef_data = ['1.Inside-Outside','2.Round','3.Top_Sirloin','4.Tenderloin',
    '5.Flap_meat','6.Striploin','7.Rib_eye','8.Skirt_meat',
    '9.Brisket','10.Clod_Chuck','11.Shin','12.Fat']
train_test_data= ['70% train, 30% test','75% train,25% test',
    '85% train, 15% test','90% train, 10% test']

ent_rnd = np.random.permutation (2)
bd_rnd = np.random.permutation (12)
ttd_rnd = np.random.permutation (4)
nhn_rnd = np.random.permutation (20)

ent = electronic_nose_type[ent_rnd[0]]
bd = beef_data[bd_rnd[0]]
ttd = train_test_data[ttd_rnd[0]]
nhn = nhn_rnd[0] + 5

print(f'Hai {student_name} ({student_id}) ! ' )
print(f'(a) Kerjakan train model electronic nose untuk <{ent}> Daging Sapi')
print(f'(b) Gunakan sheet <{bd}> pada file data sebagai dataset')
print(f'(c) Bagi dataset menjadi <{ttd}> untuk pelatihan model')
print(f'(d) Gunakan Neural Network 2 layer dengan neuron sejumlah <{nhn}> di hidden layer')
# Out:
# Hai Edwar Dendy Vatrizah (6022251057) !
# (a) Kerjakan train model electronic nose untuk <Prediksi Populasi Mikroba> Daging Sapi
# (b) Gunakan sheet <2.Round> pada file data sebagai dataset
# (c) Bagi dataset menjadi <85% train, 15% test> untuk pelatihan model
# (d) Gunakan Neural Network 2 layer dengan neuron sejumlah <21> di hidden layer
